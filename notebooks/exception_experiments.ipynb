# %%
import sys
import traceback
from logger.custom_logger import CustomLogger
logger = CustomLogger().get_logger("exception_experiments")

class DocumentPortalException(Exception):
    """
    Custom exception class for the Document Portal application.
    """

    def __init__(self, error_message, error_details: sys):
        _, _, exc_tb = error_details.exc_info()
        self.file_name = exc_tb.tb_frame.f_code.co_filename
        self.line_number = exc_tb.tb_lineno
        self.error_message = str(error_message)
        self.traceback_str = ''.join(traceback.format_exception(*error_details.exc_info()))

    def __str__(self):
        return f"""
        Error occurred in script: [ {self.file_name} ] at line number: [ {self.line_number} ]
        Error message: {self.error_message}
        Traceback details: {self.traceback_str}
        """

if __name__ == "__main__":
    try:
        a = 1 / 0
    except Exception as e:
        app_exception = DocumentPortalException(e, sys)
        logger.error(app_exception)
        raise app_exception
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 22
#      21 try:
# ---> 22     a = 1 / 0
#      23 except Exception as e:
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# DocumentPortalException                   Traceback (most recent call last)
# Cell In[3], line 26
#      24 app_exception = DocumentPortalException(e, sys)
#      25 logger.error(app_exception)
# ---> 26 raise app_exception
#
# DocumentPortalException:
#         Error occurred in script: [ C:\Users\Utkarsh\AppData\Local\Temp\ipykernel_19896\660759832.py ] at line number: [ 22 ]
#         Error message: division by zero
#         Traceback details: Traceback (most recent call last):
#   File "C:\Users\Utkarsh\AppData\Local\Temp\ipykernel_19896\660759832.py", line 22, in <module>
#     a = 1 / 0
# ZeroDivisionError: division by zero
