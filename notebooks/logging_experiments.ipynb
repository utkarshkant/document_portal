# %%
import logging
import os
from datetime import datetime

# %%
logs_dir = os.path.join(os.getcwd(), 'logs')
os.makedirs(logs_dir, exist_ok=True)

# %%
LOG_FILE = f"{datetime.now().strftime('%d-%m-%Y_%H-%M-%S')}.log"
print(LOG_FILE)

LOG_FILE_PATH = os.path.join(logs_dir, LOG_FILE)
print(LOG_FILE_PATH)
# Out:
# 28-08-2025_14-05-21.log
# d:\STUDY\LLMOPS_KN\document_portal\notebooks\logs\28-08-2025_14-05-21.log

# %%
logging.basicConfig(
    filename=LOG_FILE_PATH,
    format="[ %(asctime)s ] %(levelname)s %(name)s (line:%(lineno)d) - %(message)s",
    level=logging.INFO,
)

logger = logging.getLogger("DocumentPortal")
logger.info("this is my second log")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Structlog

# %%
import structlog
logger = structlog.get_logger()
logger.info("this is my first structlog", user_id=123, file_name="report.pdf", action="test_logging")
# Out:
# 2025-08-28 14:05:21 [info     ] this is my first structlog     action=test_logging file_name=report.pdf user_id=123
